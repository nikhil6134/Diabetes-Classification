# %%
#diabetes classification

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

dfx =  pd.read_csv("Diabetes_XTrain.csv")

dfy = pd.read_csv("Diabetes_YTrain.csv")

dfx.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            7      168             88             42      321  38.2
# 1            8      110             76              0        0  27.8
# 2            7      147             76              0        0  39.4
# 3            2      100             66             20       90  32.9
# 4            4      129             86             20      270  35.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.787   40
# 1                     0.237   58
# 2                     0.257   43
# 3                     0.867   28
# 4                     0.231   23

# %%
dfy.head()
# Out:
#    Outcome
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0

# %%
lst = dfy.values

# %%
dfx['Outcome'] = lst

# %%
dfx
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              7      168             88             42      321  38.2
# 1              8      110             76              0        0  27.8
# 2              7      147             76              0        0  39.4
# 3              2      100             66             20       90  32.9
# 4              4      129             86             20      270  35.1
# ..           ...      ...            ...            ...      ...   ...
# 571            2      111             60              0        0  26.2
# 572            7      187             68             39      304  37.7
# 573            2      122             60             18      106  29.8
# 574            4      154             72             29      126  31.3
# 575            1       88             78             29       76  32.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.787   40        1
# 1                       0.237   58        0
# 2                       0.257   43        1
# 3                       0.867   28        1
# 4                       0.231   23        0
# ..                        ...  ...      ...
# 571                     0.343   23        0
# 572                     0.254   41        1
# 573                     0.717   22        0
# 574                     0.338   37        0
# 575                     0.365   29        0
#
# [576 rows x 9 columns]

# %%
sns.barplot(x='Outcome',y='Age',data=dfx)

# %%
corr = dfx.corr()
sns.heatmap(corr)

# %%
sns.barplot(x='Outcome',y='BMI',data=dfx)

# %%
 dfx.drop(columns = ['Outcome'])
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              7      168             88             42      321  38.2
# 1              8      110             76              0        0  27.8
# 2              7      147             76              0        0  39.4
# 3              2      100             66             20       90  32.9
# 4              4      129             86             20      270  35.1
# ..           ...      ...            ...            ...      ...   ...
# 571            2      111             60              0        0  26.2
# 572            7      187             68             39      304  37.7
# 573            2      122             60             18      106  29.8
# 574            4      154             72             29      126  31.3
# 575            1       88             78             29       76  32.0
#
#      DiabetesPedigreeFunction  Age
# 0                       0.787   40
# 1                       0.237   58
# 2                       0.257   43
# 3                       0.867   28
# 4                       0.231   23
# ..                        ...  ...
# 571                     0.343   23
# 572                     0.254   41
# 573                     0.717   22
# 574                     0.338   37
# 575                     0.365   29
#
# [576 rows x 8 columns]

# %%
for i in column['Insulin']:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-92b4395be35f> in <module>
# ----> 1 for i in column['Insulin']:
#       2     print(i)
#
# NameError: name 'column' is not defined
